# %%
import xarray as xr
import glob
file_path = '/g/data/jk72/deg581/amery-hires-setup/data/proc/TSDM_2hb_199[2-3].nc'

# Load all NetCDF files
files = sorted(glob.glob(file_path))
test = xr.open_mfdataset(files, combine='by_coords')
